# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Declarando Dataframe

# %%
df = pd.read_csv('TiktokTrendingBR.csv')

# %%
df
# Out:
#         id         user_name       user_id             video_id  \
# 0        0      meekotheiggy  6.735780e+18  6928073780141018373
# 1        1  sergioconstrutor  6.860046e+18  6931147355534281990
# 2        2      callenschaub  6.658309e+18  6957448266824846598
# 3        3         muyanxu01  6.947266e+18  6955495851917692166
# 4        4      lucasranngel  1.954456e+07  6956216246446673157
# ...    ...               ...           ...                  ...
# 9995  9995       cauabipolar  6.818413e+18  6932902299882786054
# 9996  9996     dhef_almeidaa  6.609706e+18  6957075326207806725
# 9997  9997  status.reflexoes  6.935370e+18  6954279242066644229
# 9998  9998  marcelocalopsita  6.794832e+18  6930361196868537606
# 9999  9999     casalvidinhas  6.833790e+18  6959576766797106437
#
#                                              video_desc    video_time  \
# 0     Sleep = life #italiangreyhound #foryoupage #fy...  1.613068e+09
# 1                                                   NaN  1.613784e+09
# 2                 FIRST NFT “Antithesis” on foundation!  1.619907e+09
# 3                            #cat #love #kitten #foryou  1.619453e+09
# 4                        kkkkkkkk eu sou um jumento msm  1.619620e+09
# ...                                                 ...           ...
# 9995                       Resposta a @narutoxboruto004  1.614192e+09
# 9996  #dueto com @deshygirl25 vai amar o tutorial ha...  1.619820e+09
# 9997  #memes #sextou  #funny #proerd   #status #bomd...  1.619169e+09
# 9998               quem aí também é assim? 😂 #fy #viral  1.613600e+09
# 9999                                       Era trolagem  1.620403e+09
#
#       video_length                                         video_link  \
# 0             10.0  https://www.tiktok.com/@meekotheiggy/video/692...
# 1             36.0  https://www.tiktok.com/@sergioconstrutor/video...
# 2             24.0  https://www.tiktok.com/@callenschaub/video/695...
# 3              8.0  https://www.tiktok.com/@muyanxu01/video/695549...
# 4             28.0  https://www.tiktok.com/@lucasranngel/video/695...
# ...            ...                                                ...
# 9995          20.0  https://www.tiktok.com/@cauabipolar/video/6932...
# 9996           9.0  https://www.tiktok.com/@dhef_almeidaa/video/69...
# 9997          14.0  https://www.tiktok.com/@status.reflexoes/video...
# 9998          11.0  https://www.tiktok.com/@marcelocalopsita/video...
# 9999           7.0  https://www.tiktok.com/@casalvidinhas/video/69...
#
#       n_likes n_shares n_comments     n_plays         music_name  \
# 0     1000000   151600      76300  12900000.0  оригинальный звук
# 1      572800   184100       7311  31300000.0       som original
# 2     2400000     7771      27900  31000000.0     original sound
# 3      119500    32400       2293   2800000.0                 原聲
# 4      870100     2326       7576   7600000.0       som original
# ...       ...      ...        ...         ...                ...
# 9995    38100       12        230    251600.0   dc n.gabriella15
# 9996    15800     3807         65   1100000.0            Runaway
# 9997    15000     5653         29    312100.0       som original
# 9998    34000      324        161    371200.0     original sound
# 9999      798       22         24     35200.0     original sound
#
#                                             music_url;;
# 0     https://sf16-ies-music-va.tiktokcdn.com/obj/mu...
# 1     https://sf16-ies-music-va.tiktokcdn.com/obj/mu...
# 2     https://sf16-ies-music-va.tiktokcdn.com/obj/mu...
# 3     https://sf16-ies-music-va.tiktokcdn.com/obj/mu...
# 4     https://sf16-ies-music-va.tiktokcdn.com/obj/mu...
# ...                                                 ...
# 9995  https://video-va.tiktokv.com/storage/v1/tos-us...
# 9996  https://sf16-ies-music-sg.tiktokcdn.com/obj/ti...
# 9997  https://sf16-ies-music-va.tiktokcdn.com/obj/mu...
# 9998  https://sf16-ies-music-sg.tiktokcdn.com/obj/ti...
# 9999  https://sf16-ies-music-va.tiktokcdn.com/obj/mu...
#
# [10000 rows x 14 columns]

# %%
# Retirando colunas desnecessárias, setando index para o nome de usuário

# %%
df = df.drop(columns=['id','user_id', 'video_id', 'video_link', 'music_url;;','video_desc','video_time'])
df = df.drop_duplicates()
df = df.dropna()
df = df.set_index('user_name')

# %%
# Corrigindo o datatype das colunas

# %%
df['n_comments'] = pd.to_numeric(df['n_comments'], errors='coerce').astype('Int64')
df['n_plays'] = pd.to_numeric(df['n_plays'], errors='coerce').astype('Int64')
df['n_shares'] = pd.to_numeric(df['n_shares'], errors='coerce').astype('Int64')
df['n_likes'] = pd.to_numeric(df['n_likes'], errors='coerce').astype('Int64')

# %%
df
# Out:
#                   video_length  n_likes  n_shares  n_comments   n_plays  \
# user_name
# meekotheiggy              10.0  1000000    151600       76300  12900000
# sergioconstrutor          36.0   572800    184100        7311  31300000
# callenschaub              24.0  2400000      7771       27900  31000000
# muyanxu01                  8.0   119500     32400        2293   2800000
# lucasranngel              28.0   870100      2326        7576   7600000
# ...                        ...      ...       ...         ...       ...
# cauabipolar               20.0    38100        12         230    251600
# dhef_almeidaa              9.0    15800      3807          65   1100000
# status.reflexoes          14.0    15000      5653          29    312100
# marcelocalopsita          11.0    34000       324         161    371200
# casalvidinhas              7.0      798        22          24     35200
#
#                          music_name
# user_name
# meekotheiggy      оригинальный звук
# sergioconstrutor       som original
# callenschaub         original sound
# muyanxu01                        原聲
# lucasranngel           som original
# ...                             ...
# cauabipolar        dc n.gabriella15
# dhef_almeidaa               Runaway
# status.reflexoes       som original
# marcelocalopsita     original sound
# casalvidinhas        original sound
#
# [9176 rows x 6 columns]

# %%
# Gráfico para criadores mais curtidos
# Most liked creators

# %%
df = df.sort_values(by='n_likes', ascending=False)

plt.figure(figsize=(18,8))
plt.ticklabel_format(style = 'plain')
graph = sns.barplot( x = df.index[:40], y = df.n_likes[:40], hue = df.index[:40],  palette = 'Spectral', errorbar = ('ci') )
plt.xticks(rotation=90)

plt.title('Criadores Mais Curtidos')
plt.ylabel('Curtidas')
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
# Gráfico para criadores mais assistidos

# %%
df = df.sort_values(by='n_plays', ascending=False)

plt.figure(figsize=(18,8))
plt.ticklabel_format(style = 'plain')
graph = sns.barplot( x = df.index[:40], y = df.n_plays[:40], hue = df.index[:40],  palette = 'Spectral')
plt.xticks(rotation=90)

plt.title('Criadores Mais Assistidos')
plt.ylabel('Reproduções')
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
# Gráfico de duração dos videos mais assistidos

# %%
df = df.sort_values(by='n_likes', ascending=False)

plt.figure(figsize=(18,8))
plt.ticklabel_format(style = 'plain')
graph = sns.barplot(x = df.index[df.n_plays >= 25000000][:40], y = df.video_length[df.n_plays >= 25000000][:40], hue = df.index[df.n_plays >= 25000000][:40], legend = False, palette = 'Spectral', errorbar = ('ci'))

plt.xticks(rotation=90)

plt.title('Duração dos vídeos')
plt.ylabel('Duração (em segundos)')
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
#Criando outro dataframe para análise de métricas especificas

# %%
df_users = df.groupby(df.index).sum()

# %%
df_users['share_rate'] = df_users['n_shares'] / df_users['n_plays'] * 100
df_users['engagement'] = df_users['n_likes'] / df_users['n_plays'] * 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\ops\array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_users['share_rate'] = df_users['n_shares'] / df_users['n_plays'] * 100
#       2 df_users['engagement'] = df_users['n_likes'] / df_users['n_plays'] * 100
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\arraylike.py:210, in OpsMixin.__truediv__(self, other)
#     208 @unpack_zerodim_and_defer("__truediv__")
#     209 def __truediv__(self, other):
# --> 210     return self._arith_method(other, operator.truediv)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\series.py:5819, in Series._arith_method(self, other, op)
#    5817 def _arith_method(self, other, op):
#    5818     self, other = self._align_for_op(other)
# -> 5819     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\base.py:1381, in IndexOpsMixin._arith_method(self, other, op)
#    1378     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1380 with np.errstate(all="ignore"):
# -> 1381     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1383 return self._construct_result(result, name=res_name)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\ops\array_ops.py:285, in arithmetic_op(left, right, op)
#     281     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     283     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     284     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 285     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     287 return res_values
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\ops\array_ops.py:229, in _na_arithmetic_op(left, right, op, is_cmp)
#     221 except TypeError:
#     222     if not is_cmp and (
#     223         left.dtype == object or getattr(right, "dtype", None) == object
#     224     ):
#    (...)
#     227         # Don't do this for comparisons, as that will handle complex numbers
#     228         #  incorrectly, see GH#32047
# --> 229         result = _masked_arith_op(left, right, op)
#     230     else:
#     231         raise
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\ops\array_ops.py:165, in _masked_arith_op(x, y, op)
#     163     # See GH#5284, GH#5035, GH#19448 for historical reference
#     164     if mask.any():
# --> 165         result[mask] = op(xrav[mask], yrav[mask])
#     167 else:
#     168     if not is_scalar(y):
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %%
df_users = df_users.sort_values(by='share_rate', ascending=False)

plt.figure(figsize=(18,8))
plt.ticklabel_format(style = 'plain')
graph = sns.barplot(x = df_users.index[df_users.n_plays >= 25000000][:40], y = df_users.share_rate[df_users.n_plays >= 25000000][:40], hue = df_users.index[df_users.n_plays >= 25000000][:40], legend = False, palette = 'dark:#5A9_r', errorbar = ('ci'))

plt.xticks(rotation=90)

plt.title('Taxa de Compartilhamento de Criadores Grandes')
plt.ylabel('Taxa de Compartilhamento (%)')
plt.xlabel('')

print('Mediana da Taxa de Compartilhamento:', np.round(df_users['share_rate'].mean(), decimals=2), '%')

# %%
df_users = df_users.sort_values(by='engagement', ascending=False)

plt.figure(figsize=(18,8))
plt.ticklabel_format(style = 'plain')
graph = sns.barplot(x = df_users.index[df_users.n_plays >= 25000000][:40], y = df_users.engagement[df_users.n_plays >= 25000000][:40], hue = df_users.index[df_users.n_plays >= 25000000][:40], legend = False, palette = 'dark:#5A9_r', errorbar = ('ci'))

plt.xticks(rotation=90)

plt.title('Engajamento de Criadores Grandes')
plt.ylabel('Engajamento (%)')
plt.xlabel('')

print('Mediana de Engajamento:', np.round(df_users['engagement'].mean(), decimals=2), '%')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11268\1658503799.py in ?()
# ----> 1 df_users = df_users.sort_values(by='engagement', ascending=False)
#       2
#       3 plt.figure(figsize=(18,8))
#       4 plt.ticklabel_format(style = 'plain')
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6940             )
#    6941         elif len(by):
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#    6947             if key is not None:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
#    1841         elif self._is_level_reference(key, axis=axis):
#    1842             values = self.axes[axis].get_level_values(key)._values
#    1843         else:
# -> 1844             raise KeyError(key)
#    1845
#    1846         # Check for duplicates
#    1847         if values.ndim > 1:
#
# KeyError: 'engagement'

# %%
df_users = df_users.sort_values(by='engagement', ascending=False)

plt.figure(figsize=(18,8))
plt.ticklabel_format(style = 'plain')
graph = sns.scatterplot(x = df_users.index[df_users.n_plays >= 25000000][:40], y = df_users.engagement[df_users.n_plays >= 25000000][:40], hue = df_users.video_length[df_users.n_plays >= 25000000][:40], legend = False, palette = 'dark:#5A9_r', errorbar = ('ci'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11268\3045351150.py in ?()
# ----> 1 df_users = df_users.sort_values(by='engagement', ascending=False)
#       2
#       3 plt.figure(figsize=(18,8))
#       4 plt.ticklabel_format(style = 'plain')
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6940             )
#    6941         elif len(by):
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#    6947             if key is not None:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
#    1841         elif self._is_level_reference(key, axis=axis):
#    1842             values = self.axes[axis].get_level_values(key)._values
#    1843         else:
# -> 1844             raise KeyError(key)
#    1845
#    1846         # Check for duplicates
#    1847         if values.ndim > 1:
#
# KeyError: 'engagement'
