# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Declarando Dataframe

# %%
df = pd.read_csv('TiktokTrendingBR.csv')

# %%
# Retirando colunas desnecessárias, setando index para o nome de usuário

# %%
df = df.drop(columns=['id','user_id', 'video_id', 'video_link', 'music_url;;','video_desc','video_time'])
df = df.drop_duplicates()
df = df.dropna()
df = df.set_index('user_name')

# %%
# Corrigindo o datatype das colunas

# %%
df['n_comments'] = pd.to_numeric(df['n_comments'], errors='coerce').astype('Int64')
df['n_plays'] = pd.to_numeric(df['n_plays'], errors='coerce').astype('Int64')
df['n_shares'] = pd.to_numeric(df['n_shares'], errors='coerce').astype('Int64')
df['n_likes'] = pd.to_numeric(df['n_likes'], errors='coerce').astype('Int64')

# %%
df
# Out:
#                   video_length  n_likes  n_shares  n_comments   n_plays  \
# user_name
# meekotheiggy              10.0  1000000    151600       76300  12900000
# sergioconstrutor          36.0   572800    184100        7311  31300000
# callenschaub              24.0  2400000      7771       27900  31000000
# muyanxu01                  8.0   119500     32400        2293   2800000
# lucasranngel              28.0   870100      2326        7576   7600000
# ...                        ...      ...       ...         ...       ...
# cauabipolar               20.0    38100        12         230    251600
# dhef_almeidaa              9.0    15800      3807          65   1100000
# status.reflexoes          14.0    15000      5653          29    312100
# marcelocalopsita          11.0    34000       324         161    371200
# casalvidinhas              7.0      798        22          24     35200
#
#                          music_name
# user_name
# meekotheiggy      оригинальный звук
# sergioconstrutor       som original
# callenschaub         original sound
# muyanxu01                        原聲
# lucasranngel           som original
# ...                             ...
# cauabipolar        dc n.gabriella15
# dhef_almeidaa               Runaway
# status.reflexoes       som original
# marcelocalopsita     original sound
# casalvidinhas        original sound
#
# [9176 rows x 6 columns]

# %%
# Gráfico para criadores mais curtidos
# Most liked creators

# %%
df = df.sort_values(by='n_likes', ascending=False)

plt.figure(figsize=(18,8))
plt.ticklabel_format(style = 'plain')
graph = sns.barplot( x = df.index[:40], y = df.n_likes[:40], hue = df.index[:40],  palette = 'Spectral', errorbar = ('ci') )
plt.xticks(rotation=90)

plt.title('Criadores Mais Curtidos')
plt.ylabel('Curtidas')
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
# Gráfico para criadores mais assistidos
# Most watched creators

# %%
df = df.sort_values(by='n_plays', ascending=False)

plt.figure(figsize=(18,8))
plt.ticklabel_format(style = 'plain')
graph = sns.barplot( x = df.index[:40], y = df.n_plays[:40], hue = df.index[:40],  palette = 'Spectral')
plt.xticks(rotation=90)

plt.title('Criadores Mais Assistidos')
plt.ylabel('Reproduções')
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
# Gráfico de duração dos videos mais assistidos

# %%
df = df.sort_values(by='n_likes', ascending=False)

plt.figure(figsize=(18,8))
plt.ticklabel_format(style = 'plain')
graph = sns.barplot(x = df.index[df.n_plays >= 25000000][:40], y = df.video_length[df.n_plays >= 25000000][:40], hue = df.index[df.n_plays >= 25000000][:40], legend = False, palette = 'Spectral', errorbar = ('ci'))

plt.xticks(rotation=90)

plt.title('Duração dos vídeos')
plt.ylabel('Duração (em segundos)')
plt.xlabel('')

# Usuario, Interação e Duração
# Out:
# Text(0.5, 0, '')

# %%
df_users = df.groupby(df.index).sum()

# %%
df_users['share_rate'] = df_users['n_shares'] / df_users['n_plays'] 
df_users['engagement'] = df_users['n_likes'] / df_users['n_plays']

# %%
df_users = df_users.sort_values(by='share_rate', ascending=False)

# %%
df_users[df_users.n_plays >= 25000000][:40]
# Out:
#                     video_length   n_likes  n_shares  n_comments    n_plays  \
# user_name
# jobsonamancio              234.0   2711000    600890       22822   29033300
# missymarcier__              29.0   8400000    766900      235600   49700000
# _cacesa                    290.0   4257600    411080       39286   29967000
# simbachboy                  26.0   1246600    530100       18363   42300000
# diiferrer                   26.0   1660600    309461       14002   27400000
# enok0806                   253.0   2146967    524813       33098   46815800
# karolinehss_                13.0   1700000    396900       48100   35900000
# juan_oficial_1              32.0    499900    260700        1376   25400000
# foodqood                    26.0   1862300    377500        8672   42600000
# canalzezao                  44.0   1738100    256600       24193   29100000
# euorlandinho               197.0   5103100    591600       68958   67800000
# dmitryhitr                  12.0   6200000    230100       58600   26500000
# xorte.sere.kaniya           23.0   1700000    288000       22900   34600000
# sausampaio                 313.0   4107700    320975       59879   38713000
# manusurtiktok                7.0   1600000    209800       31900   25400000
# jaykingnegpain_an           10.0    285900    197000        6198   25200000
# vittorfernando             708.0  14696900    668914      189698   85778400
# tiriricanaweb              239.0   2077100    331639       19287   44825700
# joaoferdnan22              243.0   6938500    337565       86734   48015500
# insecthaus_adi              10.0   3300000    271700      282900   40700000
# agama_mama                  45.0   4800000    175800      108400   26800000
# tirullipa                  734.0   7044000    739803       60078  115979700
# peritore7_official          14.0   7300000    296600      132000   48000000
# attilathebum                12.0   1800000    188100       27300   31200000
# rafaelcunhaof              157.0   1728700    160456       13061   26889800
# sergioconstrutor            36.0    572800    184100        7311   31300000
# antony.cantor              156.0   1637500    152481       13101   27600000
# stefanbute18                59.0   2800000    399200       19600   76800000
# furacao_deus                65.0   1010100    131039       17302   25268100
# aninhah2                    23.0   1936400    198251       29566   38400000
# humankind                   52.0   4500000    125300       66900   25300000
# chipmunksoftiktok           15.0  19900000    900700      331700  182100000
# nicnadyya                  554.0   4330300    123450       52347   25084500
# mada_e_bica                248.0   4198400    168115       49470   34255300
# londrinando                125.0   2362800    143205       45009   29437600
# pkllipe                    968.0  17083200    390122      202222   82968200
# gabihaxkar                 133.0   2149500    118495       18882   26421400
# sulavshrestha60             15.0    743800    229700        5461   52100000
# isaiaslvas                 628.0  10774600    280707       85208   66257400
# gutierrezcastro            292.0  14898500    380531      120383   91556000
#
#                                                            music_name  \
# user_name
# jobsonamancio       Met Him Last NightUp Beat (Married Life)Met Hi...
# missymarcier__                               Monkeys Spinning Monkeys
# _cacesa             som originalsom originalsom originalsom origin...
# simbachboy                                      Lambadaoriginal sound
# diiferrer                                    som originalsom original
# enok0806            som originalsom originalsom originalsom origin...
# karolinehss_                                             som original
# juan_oficial_1                    Astronomiasonido originalAstronomia
# foodqood                                             CradlesBreakfast
# canalzezao          Apaga a Luz Apaga Tudo 150BpmNão Pode Se Apaix...
# euorlandinho        som originalsom originalLinda Bela - Ao Vivoso...
# dmitryhitr                                          оригинальный звук
# xorte.sere.kaniya                                        الصوت الأصلي
# sausampaio          Preta do Cabelo Cacheadosom originalsom origin...
# manusurtiktok                                         Let's Get It On
# jaykingnegpain_an                                        son original
# vittorfernando      Monkeys Spinning Monkeyssom originalsom origin...
# tiriricanaweb       som originalsom originalsom originalsom origin...
# joaoferdnan22       som originalsom originalsom originalsom origin...
# insecthaus_adi                                         original sound
# agama_mama                                   Celebrate the Good Times
# tirullipa           som originalsom originalsom originalsom origin...
# peritore7_official                                        Originalton
# attilathebum                                          Pump Up The Jam
# rafaelcunhaof       som originalsom originalsom originalsom origin...
# sergioconstrutor                                         som original
# antony.cantor       som originalVou Falar Que Não Quero - RemixA R...
# stefanbute18                                           sunet original
# furacao_deus         som originalsom originalsom originalsom original
# aninhah2                                     som originalsom original
# humankind                         Rex Orange County - Pluto Projector
# chipmunksoftiktok                                      original sound
# nicnadyya           original soundoriginal soundoriginal soundorig...
# mada_e_bica         Beije seu Petsom originalsom originaloriginal ...
# londrinando         som originalsom originalsom originalMonkeys Sp...
# pkllipe             som originalsom originalsom originalsom origin...
# gabihaxkar          som originalXerecardsom originalsom originalso...
# sulavshrestha60                                        original sound
# isaiaslvas          som originalsom originalsom originalsom origin...
# gutierrezcastro     som originalsom originalsom originalsom origin...
#
#                     share_rate  engagement
# user_name
# jobsonamancio         0.020697    0.093376
# missymarcier__        0.015431    0.169014
# _cacesa               0.013718    0.142076
# simbachboy            0.012532     0.02947
# diiferrer             0.011294    0.060606
# enok0806               0.01121     0.04586
# karolinehss_          0.011056    0.047354
# juan_oficial_1        0.010264    0.019681
# foodqood              0.008862    0.043716
# canalzezao            0.008818    0.059729
# euorlandinho          0.008726    0.075267
# dmitryhitr            0.008683    0.233962
# xorte.sere.kaniya     0.008324    0.049133
# sausampaio            0.008291    0.106106
# manusurtiktok          0.00826    0.062992
# jaykingnegpain_an     0.007817    0.011345
# vittorfernando        0.007798    0.171336
# tiriricanaweb         0.007398    0.046337
# joaoferdnan22          0.00703    0.144505
# insecthaus_adi        0.006676    0.081081
# agama_mama             0.00656    0.179104
# tirullipa             0.006379    0.060735
# peritore7_official    0.006179    0.152083
# attilathebum          0.006029    0.057692
# rafaelcunhaof         0.005967    0.064288
# sergioconstrutor      0.005882      0.0183
# antony.cantor         0.005525     0.05933
# stefanbute18          0.005198    0.036458
# furacao_deus          0.005186    0.039975
# aninhah2              0.005163    0.050427
# humankind             0.004953    0.177866
# chipmunksoftiktok     0.004946    0.109281
# nicnadyya             0.004921    0.172629
# mada_e_bica           0.004908    0.122562
# londrinando           0.004865    0.080265
# pkllipe               0.004702    0.205901
# gabihaxkar            0.004485    0.081355
# sulavshrestha60       0.004409    0.014276
# isaiaslvas            0.004237    0.162617
# gutierrezcastro       0.004156    0.162726
